# %%
import pandas as pd

# %%
train = pd.read_csv('./data/train_data.csv')
test = pd.read_csv('./data/test_data.csv')

# %%
train
# Out:
#      Unnamed: 0  BID_PRICE                                            CONTENT  \
# 0           694      74.00  Chuyên gia nhận định các yếu tố đang nghiêng v...
# 1           638      70.10  Giá vàng giằng co trước những diễn biến khó đo...
# 2           133      54.10  Giá vàng hôm nay ngày 02/12: Sau nhiều diễn bi...
# 3           355      69.55  . Giá vàng năm châu không ngừng cắm đầu lao dố...
# 4            55      60.60  Giá vàng lúc 9h34 ngày 7/8/2020 tiếp tục lập đ...
# ..          ...        ...                                                ...
# 618          71      55.25  Giá vàng hôm nay lúc 10h30 ngày 27/8/2020 tăng...
# 619         106      55.88  Giá vàng hôm nay ngày 23/10/2020 giảm từ 120.0...
# 620         270      56.30  Giá vàng hôm nay ngày 9/8/2021 giảm từ 100.000...
# 621         435      65.55  . Giá vàng năm châu không ngừng lùi sâu trong ...
# 622         102      55.75  Giá vàng hôm nay ngày 19/10/2020 giảm từ 20.00...
#
#            DATE  PRICE   TIME  \
# ...

# %%
for i in range(3, 4):
    print(train.iloc[i].DATE)
    print(train.iloc[i].TITLE)
    print(train.iloc[i].CONTENT)
    print(train.iloc[i].labels)
# Out:
# 20/04/2022
# Giá vàng hôm nay 20/4: Hụt hơi, vàng quay đầu giảm sốc
# . Giá vàng năm châu không ngừng cắm đầu lao dốc trong phiên mua bán sáng hôm nay.
#  khi 8h30 sáng ngày hôm nay ( 20/4, theo giờ nước ta ) , giá vàng toàn cầu mua bán ở mức 1 .944 usd/ounce, lao dốc 32 usd/ounce đối chiếu với cùng giờ sáng qua .
#  giá vàng sáng ngày hôm nay lao dốc hầu hết là bởi đồng usd chạm mức kỷ lục trong hai năm và lợi suất trái phiếu thời gian một thập niên của mỹ đã được tăng lên gần 3% - mức kỷ lục tính từ giữa tháng ba/2018. Cục tích trữ liên bang mỹ ( fed ) dự tính sẽ mạnh tay hơn trong lĩnh vực bó chặt chính sách tiền tệ. Trong hội nghị tháng năm, có thể fed sẽ tăng lợi tức thêm 50 điểm căn bản để giảm nhiệt lạm phát.
#  trong khi ấy, chứng khoán mỹ đêm hôm trước cùng lúc xanh sàn, chứng minh một phần dòng vốn trên khu vực kinh doanh đang dồn vào cổ phiếu.
# ...
