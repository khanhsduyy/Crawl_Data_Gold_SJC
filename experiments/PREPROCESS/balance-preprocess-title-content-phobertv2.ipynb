# %%
# !pip install py_vncorenlp -q  # Cài đặt thư viện VnCoreNLP cho xử lý ngôn ngữ tự nhiên tiếng Việt

# %%
import pandas as pd
from torch.utils.data import DataLoader, Dataset
from accelerate import Accelerator, notebook_launcher
from transformers import AutoModelForSequenceClassification, RobertaForSequenceClassification, AutoTokenizer, get_scheduler, AutoModel
from torch.optim import AdamW
from accelerate.utils import set_seed
import torch
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from py_vncorenlp import  VnCoreNLP
import py_vncorenlp
import re

# %%
# Automatically download VnCoreNLP components from the original repository
# and save them in some local machine folder
py_vncorenlp.download_model(save_dir='./')

# %%
# !apt-get update
# !apt-get install -y openjdk-11-jdk-headless -qq > /dev/null
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:2 http://archive.ubuntu.com/ubuntu focal-updates InRelease [128 kB]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease [1581 B]
# Hit:4 https://packages.cloud.google.com/apt gcsfuse-focal InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu focal-backports InRelease
# Get:6 http://security.ubuntu.com/ubuntu focal-security InRelease [128 kB]
# Get:7 https://packages.cloud.google.com/apt cloud-sdk InRelease [1616 B]
# Get:8 https://packages.cloud.google.com/apt google-fast-socket InRelease [5015 B]
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  Packages [1617 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [4156 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1509 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 Packages [3776 kB]
# Get:13 https://packages.cloud.google.com/apt cloud-sdk/main all Packages [1454 kB]
# Get:14 https://packages.cloud.google.com/apt cloud-sdk/main amd64 Packages [3017 kB]
# Get:15 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1211 kB]
# Get:16 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [3680 kB]
# Get:17 http://security.ubuntu.com/ubuntu focal-security/restricted amd64 Packages [3626 kB]
# Fetched 24.3 MB in 12s (1965 kB/s)
# Reading package lists... Done

# %%
# Load the word and sentence segmentation component
rdrsegmenter = py_vncorenlp.VnCoreNLP(annotators=["wseg"], save_dir='./')
# Out:
# 2024-06-08 08:57:11 INFO  WordSegmenter:24 - Loading Word Segmentation model

# %%
train = pd.read_csv('/kaggle/input/balance-gold-dataset/balance_train.csv', sep=',')

# %%
test = pd.read_csv('/kaggle/input/balance-gold-dataset/balance_test.csv', sep=',')

# %%
train.head()
# Out:
#    BID_PRICE                                            CONTENT        DATE  \
# 0      66.50  Lợi suất trái phiếu toàn cầu đang tăng lên, đi...  24/06/2023
# 1      67.65  Tài khoản không đủ để thực hiện chức năng này....  14/07/2022
# 2      56.75  Giá vàng hôm nay ngày 12/7/2021 biến động từ g...  12/07/2021
# 3      68.20  Hôm qua, thị trường nhận thông tin về báo cáo ...  05/10/2023
# 4      74.30  Giá vàng bật tăng khi căng thẳng quân sự leo t...  30/01/2024
#
#    PRICE   TIME                                              TITLE    labels
# 0  67.10  08:30  Giá vàng hôm nay 24/6: Vọt lên cao rồi cắm đầu...  increase
# 1  68.25  09:00  Giá vàng hôm nay 14/7: Vàng trong nước tăng ng...  increase
# 2  57.50  08:55  Giá vàng hôm nay ngày 12/7/2021: biến động nhẹ...  decrease
# 3  68.90  09:20  Giá vàng hôm nay 5/10: Chuyên gia dự đoán lạc ...  decrease
# 4  76.80  08:55  Giá vàng hôm nay 30/1: Nhiều yếu tố hỗ trợ, và...  increase

# %%
test.head()
# Out:
#    BID_PRICE                                            CONTENT        DATE  \
# 0      67.85  . Sự tin tưởng của khu vực kinh doanh vào một ...  25/06/2022
# 1      82.80  Xu hướng mua ròng vàng miếng của các quốc gia ...  10/04/2024
# 2      66.45  Mặc dù tâm lý lạc quan đã quay trở lại nhưng h...  10/07/2023
# 3      56.35  Giá vàng hôm nay ngày 5/1/2021 tăng từ 50.000 ...  05/01/2021
# 4      68.80  . Giá vàng tiếp đà tăng khi thị trường tài chí...  09/06/2022
#
#    PRICE   TIME                                              TITLE    labels
# 0  68.65  09:45  Giá vàng hôm nay 25/6: "Hụt hơi" phiên cuối tu...  decrease
# 1  84.80  08:20  Giá vàng hôm nay 10/4: Sau "cơn điên" tăng giá...  increase
# 2  67.05  08:30  Giá vàng hôm nay 10/7: Vàng đi ngang, giới đầu...  decrease
# 3  56.90  10:20  Giá vàng hôm nay ngày 5/1/2021: vàng tiếp tục ...  increase
# 4  69.70  08:30  Giá vàng hôm nay 9/6: Được hỗ trợ mạnh, vàng p...  increase

# %%
def get_config():
    config = {'batch_size': 16,
              'model_name': 'vinai/phobert-base-v2',
              'lr': 10 ** -5,
              'num_labels': 2,
              'epochs': 10,
              'num_warmup_steps': 0,
              'seed': 42, 
              'max_length': 256,
              'eos': '[SEP]'
              
    }
    return config

# %%
config = get_config()

# %% [markdown]
# ### Preprocessing

# %%
def preprocess(text):
    # Loại bỏ các ký tự xuống dòng và thay thế chúng bằng một khoảng trắng
    text = re.sub(r'\r\n+', ' ', text)
    
    # Chuẩn hóa khoảng trắng để không có nhiều khoảng trắng liên tiếp
    text = re.sub(r'\s+', ' ', text)
    
    # Loại bỏ dấu câu
    text = re.sub(r'[^\w\s/]', '', text)
    
    # Thêm dấu chấm câu để tách các câu
    text = re.sub(r'(\d+)([a-zA-Z])', r'\1 \2', text)  # Thêm khoảng trắng giữa số và chữ
    text = re.sub(r'(?<=\d)(?=[a-zA-Z])', ' ', text)   # Thêm khoảng trắng giữa số và chữ nếu không có khoảng trắng
    text = re.sub(r'(?<=[a-zA-Z])(?=\d)', ' ', text)   # Thêm khoảng trắng giữa chữ và số nếu không có khoảng trắng
    text = re.sub(r'(đồng lượng|usdoz|lượng)', r'\1.', text)  # Thêm dấu chấm sau các đơn vị đo lường
    
    # Loại bỏ khoảng trắng thừa ở đầu và cuối chuỗi
    text = text.strip()

    # Chuyển thành chữ thường
    text = text.lower()

    return text

# %%
train['TITLE'] = train['TITLE'].apply(lambda x: preprocess(x))
train['CONTENT'] = train['CONTENT'].apply(lambda x: preprocess(x))
test['TITLE'] = test['TITLE'].apply(lambda x: preprocess(x))
test['CONTENT'] = test['CONTENT'].apply(lambda x: preprocess(x))

# %% [markdown]
# ### Creating dataset

# %%
class get_dataset(Dataset):
    def __init__(self, df: pd.DataFrame) -> None:
        super().__init__()
        self.titles = df['TITLE'].values
        self.content = df['CONTENT'].values
        self.labels = df['labels'].values

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        title = self.titles[idx]
        content = self.content[idx]
        if self.labels[idx] == "increase":
            label = 1
        elif self.labels[idx] == "decrease":
            label = 0
        input_data = rdrsegmenter.word_segment(title)[0] + '[SEP]' + rdrsegmenter.word_segment(content)[0]

        return input_data, label

# %%
train_dataset = get_dataset(df=train)
test_dataset  = get_dataset(df=test)

# %%
train_dataset[222]
# Out:
# ('giá vàng hôm_nay 12/9 tăng dè_dặt chờ thông_tin mới[SEP]giá quý kim bật tăng trong phiên đầu tuần do đồng usd suy_yếu tuy_nhiên mức tăng này không giữ được lâu thời_điểm 8 h 45 sáng nay ngày 12/9 theo giờ việt_nam giá vàng thế_giới đứng ở mức 1921 usd / ounce giảm nhẹ 1 usd / ounce so với cùng giờ sáng_qua giá quý kim bật tăng trong phiên đầu tuần do đồng usd suy_yếu tuy_nhiên mức tăng này không giữ được lâu vàng quay đầu giảm_giá về vùng giá chốt phiên tuần trước thị_trường đang chờ_đợi dữ_liệu lạm_phát để có thêm manh_mối về hướng đi sắp tới của cục dự_trữ liên_bang mỹ fed cụ_thể báo_cáo chỉ_số giá tiêu_dùng tháng 8 sẽ được công_bố vào sáng thứ 4 cpi dự_kiến tăng 43 so với cùng kỳ năm trước so với mức tăng 47 trong báo_cáo tháng 7 thông_tin về cuộc họp chính_sách của ngân_hàng trung_ương châu_âu trong tuần này cũng được giới đầu_tư quan_tâm dự_kiến ngân_hàng này sẽ tăng nhẹ lãi_suất thêm 25 điểm cơ_bản nhiều nhà_phân_tích đã lưu_ý rằng vàng đang nằm trong phạm_vi giao_dịch trung_lập do lĩnh_vực này tiếp_tục bị chi_phối bởi lợi_suất trái_phiếu tăng và sức_mạnh vững_chắc của đồng usd trước đó cũng theo reuters matt simpson nhà_phân_tích cấp cao tại công_ty dịch_vụ tài_chính city index cho rằng giá vàng sẽ được hỗ_trợ trên mức 1900 usd / ounce nếu đồng usd tiếp_tục giảm do những dự_báo cho rằng fed thực_sự đã hoàn_tất chu_kỳ thắt chặt chính_sách tiền_tệ ông simpson nói giá vàng đã tìm thấy mức hỗ_trợ quanh mức dao_động trung_bình 200 ngày_một ngưỡng kỹ_thuật quan_trọng không dễ bị phá vỡ marc chandler giám_đốc_điều_hành của bannockburn global forex dự_báo thời_gian tới giá vàng sẽ nằm trong vùng kháng_cự 1935 1940 usd / ounce nếu vàng vượt qua mức đó có_thể lên ở mức 1950 usd / ounce mặt_khác nếu không_thể vượt qua mức 1915 usd / ounce vàng có_thể quay lại mức 1900 usd / ounce ở thị_trường trong nước mở_cửa phiên giao_dịch sáng nay công_ty vàng_bạc đá_quý sài_gòn niêm_yết giá vàng sjc mua vào bán ra ở mức 6815 6887 triệu đồng / lượng . giảm 50000 đồng / lượng . so với chốt phiên hôm_qua vàng doji hn niêm_yết giá vàng ở mức 681 689 triệu đồng / lượng . giữ nguyên so với phiên gần nhất vàng pnj niêm_yết giá vàng sjc ở mức 682 689 triệu đồng / lượng . chưa đổi so với phiên liền trước giá quý kim vừa trải qua một tuần giảm hơn 1 thi thiếu các dữ_liệu kinh_tế và các sự_kiện kích_thích thị_trường',
#  1)

# %%
def create_dataloader(dataset: Dataset, config: dict, is_train: bool) -> DataLoader:

    return DataLoader(dataset=dataset, batch_size=config['batch_size'], shuffle=is_train, drop_last=is_train)

# %%
train_loader = create_dataloader(train_dataset, config, True)
test_loader  = create_dataloader(test_dataset, config, False)

# %% [markdown]
# ### Training

# %%
config['model_name']
# Out:
# 'vinai/phobert-base-v2'

# %%
tokenizer = AutoTokenizer.from_pretrained(config['model_name'])
# Out:
# /opt/conda/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %% [markdown]
# ### Training

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# create model
model = AutoModelForSequenceClassification.from_pretrained(config['model_name'], num_labels=config['num_labels'])

# create optimizer
optimizer = AdamW(params=model.parameters(), lr=config['lr'])

train_loader = create_dataloader(train_dataset, config, True)
test_loader = create_dataloader(test_dataset, config, False)

num_training_steps = config['epochs'] * len(train_loader)
# create lr scheduler
lr_scheduler = get_scheduler(
    'cosine', optimizer=optimizer, num_warmup_steps=config['num_warmup_steps'], num_training_steps=num_training_steps
)

# create loss function
loss_fn = torch.nn.CrossEntropyLoss()

model.to(device)
epochs = config['epochs']

# Early stopping parameters
patience = 2
best_eval_loss = float('inf')
early_stopping_counter = 0
# Out:
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at vinai/phobert-base-v2 and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# training
print("========== Start training ==========")
for epoch in range(epochs):
    model.train()
    training_loss = 0
    for inputs, labels in train_loader:
        inputs = tokenizer(inputs, return_tensors='pt', max_length=config['max_length'], padding='longest', truncation=True).to(device)
        labels = labels.to(device)

        outputs = model(**inputs, labels=labels)
        loss = outputs.loss
        training_loss += loss.item()

        loss.backward()
        optimizer.step()
        lr_scheduler.step()
        optimizer.zero_grad()

    training_loss /= len(train_loader)

    # testing
    eval_loss = 0
    model.eval()
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs = tokenizer(inputs, return_tensors='pt', max_length=config['max_length'], padding='longest', truncation=True).to(device)
            labels = labels.to(device)

            outputs = model(**inputs, labels=labels)
            loss = outputs.loss
            eval_loss += loss.item()

    eval_loss /= len(test_loader)
    print(f"Epoch {epoch + 1}, Training loss: {training_loss:.4f}, Eval loss: {eval_loss:.4f}")

    # Check for early stopping
    if eval_loss < best_eval_loss:
        best_eval_loss = eval_loss
        early_stopping_counter = 0
    else:
        early_stopping_counter += 1

    if early_stopping_counter >= patience:
        print("Early stopping triggered")
        break

print("========== End training ==========")
# Out:
# ========== Start training ==========
# Epoch 1, Training loss: 0.6932, Eval loss: 0.6563
# Epoch 2, Training loss: 0.5133, Eval loss: 0.2891
# Epoch 3, Training loss: 0.2794, Eval loss: 0.2498
# Epoch 4, Training loss: 0.1830, Eval loss: 0.1853
# Epoch 5, Training loss: 0.1551, Eval loss: 0.1882
# Epoch 6, Training loss: 0.1163, Eval loss: 0.1885
# Early stopping triggered
# ========== End training ==========

# %% [markdown]
# ### Inference

# %%
preds = []

# %%
model.eval()
with torch.no_grad(): 
    for inputs, labels in test_loader:
        inputs = tokenizer(inputs, return_tensors='pt', max_length=config['max_length'], padding='longest', truncation=True).to(device)
        outputs = model(**inputs)
        probs = torch.nn.functional.softmax(outputs.logits, dim=1)
        _, predicted_labels = torch.max(probs, dim=1)
        preds.extend(predicted_labels.detach().cpu().tolist())

# %%
labels = test['labels'].values
labels = [1 if label == 'increase' else 0 for label in labels]

# %%
acc  = accuracy_score(labels, preds)
precision = precision_score(labels, preds)
recall = recall_score(labels, preds)
f1 = f1_score(labels, preds)

# %%
print(f"========== Evaluation Metrics ==========")
print(f"Accuracy  : {acc:.4f}")
print(f"Precision : {precision:.4f}")
print(f"Recall    : {recall:.4f}")
print(f"F1 Score  : {f1:.4f}")
print(f"========================================")
# Out:
# ========== Evaluation Metrics ==========
# Accuracy  : 0.9459
# Precision : 0.9600
# Recall    : 0.9351
# F1 Score  : 0.9474
# ========================================

# %% [markdown]
# Confusion metrics

# %%
cfn = confusion_matrix(labels, preds)
print(f"Confusion matrix is: {cfn}")
ConfusionMatrixDisplay.from_predictions(labels, preds)
plt.title('Confusion matrix')
plt.savefig("confusion_matrix.pdf", format='pdf')
plt.show()
# Out:
# Confusion matrix is: [[68  3]
#  [ 5 72]]

# %% [markdown]
# ### Analysis

# %%
wrong_indices = [i for i, (pred, label) in enumerate(zip(preds, labels)) if pred != label]

# %%
wrong_indices
# Out:
# [44, 45, 70, 74, 101, 107, 122, 123]

# %%
wrong_samples = test.iloc[wrong_indices]

# %%
wrong_samples['preds'] = [preds[i] for i in wrong_indices]

# %%
wrong_samples.drop(['BID_PRICE', 'PRICE', 'TIME'], axis=1, inplace=True)

# %%
wrong_samples['preds'] = wrong_samples['preds'].apply(lambda x: 'decrease' if x == 0 else 'increase')

# %%
wrong_samples
# Out:
#                                                CONTENT        DATE  \
# 44   tài khoản không đủ để thực hiện chức năng này ...  19/07/2022
# 45   giá vàng hôm nay ngày 3/11/2021 giảm từ 50000 ...  03/11/2021
# 70   đêm qua đã có lúc giá quý kim bất ngờ vọt lên ...  11/05/2023
# 74   thị trường đang diễn ra một số hoạt động được ...  29/03/2023
# 101  giá vàng giảm nhẹ là phản ứng trước áp lực lạm...  01/09/2023
# 107  giá vàng lúc 09 h 33 ngày 13/8/2020 phục hồi l...  13/08/2020
# 122  giá vàng thế giới quay đầu giảm mạnh trong phi...  14/05/2024
# 123  giá vàng giảm sâu khi phản ứng ban đầu với báo...  07/10/2023
#
#                                                  TITLE    labels     preds
# 44   giá vàng hôm nay 19/7 giới đầu cơ tiếp tục bán...  increase  decrease
# 45           giá vàng hôm nay ngày 3/11/2021 vàng giảm  increase  decrease
# 70       giá vàng hôm nay 11/5 vọt lên cao rồi lao dốc  increase  decrease
# 74   giá vàng hôm nay 29/3 tăng nhẹ chuyên gia dự đ...  decrease  increase
# 101  giá vàng hôm nay 1/9 mở đầu tháng mới vàng giả...  increase  decrease
# 107   giá vàng ngày 13/8/2020 phục hồi về mốc 56 triệu  decrease  increase
# 122  giá vàng hôm nay 14/5 liên tục biến động vàng ...  increase  decrease
# 123  giá vàng hôm nay 7/10 phục hồi mạnh mẽ phiên c...  decrease  increase

# %%
wrong_samples['TITLE'].values
# Out:
# array(['giá vàng hôm nay 19/7 giới đầu cơ tiếp tục bán tháo giá vàng tại việt nam ra sao',
#        'giá vàng hôm nay ngày 3/11/2021 vàng giảm',
#        'giá vàng hôm nay 11/5 vọt lên cao rồi lao dốc',
#        'giá vàng hôm nay 29/3 tăng nhẹ chuyên gia dự đoán lạc quan',
#        'giá vàng hôm nay 1/9 mở đầu tháng mới vàng giảm nhẹ',
#        'giá vàng ngày 13/8/2020 phục hồi về mốc 56 triệu',
#        'giá vàng hôm nay 14/5 liên tục biến động vàng sjc bất ngờ giảm mạnh trước phiên đấu thầu',
#        'giá vàng hôm nay 7/10 phục hồi mạnh mẽ phiên cuối tuần'],
#       dtype=object)
